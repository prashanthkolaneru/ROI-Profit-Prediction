# %% [markdown]
# # STEP -1 DATA INGESTION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Dataset = pd.read_csv(r'C:/Users/User/50_startups.csv')

# %%
Dataset.head()
# Out:
#    Research   Office Administration  Digital Marketing     Region  ROI Profit
# 0  280753.20              149397.80          516784.10  Telangana   197261.83
# 1  278001.70              163877.59          488898.53      Assam   196792.06
# 2  268845.51              113645.55          452934.54  Karnataka   196050.39
# 3  259776.41              131171.85          428199.62  Telangana   187901.99
# 4  257511.34              103891.77          411168.42  Karnataka   171187.94

# %% [markdown]
# # STEP -2 DATA MODELLING

# %%
X = Dataset.iloc[:,:-1].values
y = Dataset.iloc[:,4].values

# %%
# %matplotlib inline
import seaborn as sns
sns.pairplot(Dataset)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:,3] = labelencoder.fit_transform(X[:,3])

# %%
X
# Out:
# array([[280753.2, 149397.8, 516784.1, 2],
#        [278001.7, 163877.59, 488898.53, 0],
#        [268845.51, 113645.55, 452934.54, 1],
#        [259776.41, 131171.85, 428199.62, 2],
#        [257511.34, 103891.77, 411168.42, 1],
#        [247280.9, 112314.71, 407861.36, 2],
#        [250019.46, 159698.87, 172716.82, 0],
#        [245702.13, 158030.06, 368876.68, 1],
#        [235946.52, 161218.95, 356613.29, 2],
#        [238738.88, 121179.17, 349981.62, 0],
#        [217317.08, 123094.11, 274160.95, 1],
#        [216075.96, 104290.61, 294744.55, 0],
#        [209267.75, 139820.38, 294839.44, 1],
#        [207396.39, 147995.07, 297664.93, 0],
#        [235347.24, 169047.42, 301512.92, 1],
#        [229927.61, 135116.84, 306776.23, 2],
#        [193417.11, 134097.55, 309346.06, 0],
#        [210061.16, 157577.58, 327574.31, 2],
#        [207153.16, 126675.79, 339919.57, 1],
#        [201823.7, 166014.11, 45000.0, 2],
#        [191657.86, 126367.3, 343664.47, 0],
# ...

# %%
onehotencoder = OneHotEncoder(categorical_features=[3])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
X
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 2.8075320e+05,
#         1.4939780e+05, 5.1678410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.7800170e+05,
#         1.6387759e+05, 4.8889853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 2.6884551e+05,
#         1.1364555e+05, 4.5293454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 2.5977641e+05,
#         1.3117185e+05, 4.2819962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 2.5751134e+05,
#         1.0389177e+05, 4.1116842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 2.4728090e+05,
#         1.1231471e+05, 4.0786136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 2.5001946e+05,
#         1.5969887e+05, 1.7271682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 2.4570213e+05,
#         1.5803006e+05, 3.6887668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 2.3594652e+05,
#         1.6121895e+05, 3.5661329e+05],
# ...

# %%
X = X[:,1:]

# %%
X
# Out:
# array([[0.0000000e+00, 1.0000000e+00, 2.8075320e+05, 1.4939780e+05,
#         5.1678410e+05],
#        [0.0000000e+00, 0.0000000e+00, 2.7800170e+05, 1.6387759e+05,
#         4.8889853e+05],
#        [1.0000000e+00, 0.0000000e+00, 2.6884551e+05, 1.1364555e+05,
#         4.5293454e+05],
#        [0.0000000e+00, 1.0000000e+00, 2.5977641e+05, 1.3117185e+05,
#         4.2819962e+05],
#        [1.0000000e+00, 0.0000000e+00, 2.5751134e+05, 1.0389177e+05,
#         4.1116842e+05],
#        [0.0000000e+00, 1.0000000e+00, 2.4728090e+05, 1.1231471e+05,
#         4.0786136e+05],
#        [0.0000000e+00, 0.0000000e+00, 2.5001946e+05, 1.5969887e+05,
#         1.7271682e+05],
#        [1.0000000e+00, 0.0000000e+00, 2.4570213e+05, 1.5803006e+05,
#         3.6887668e+05],
#        [0.0000000e+00, 1.0000000e+00, 2.3594652e+05, 1.6121895e+05,
#         3.5661329e+05],
#        [0.0000000e+00, 0.0000000e+00, 2.3873888e+05, 1.2117917e+05,
#         3.4998162e+05],
# ...

# %% [markdown]
# # STEP -3 DATA SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.25,random_state = 0)

# %% [markdown]
# # STEP -4 MODEL CREATION

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # STEP -5 MODEL PREDICTION

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([115767.64544637, 132922.95264788, 127840.27093611,  79717.23950908,
#        164690.79812416, 128391.32647668,  78215.08085137, 110248.66602365,
#        120344.62757375, 154130.93056533, 101038.72952614,  96786.70157186,
#        114203.82125494])

# %% [markdown]
# # STEP -6 MODEL EVALUATION

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 14333.393261877352

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.8095590702347928

# %%
regressor.score(X_test,y_test)
# Out:
# 0.8095590702347928

# %% [markdown]
# # STEP -7 MODEL TESTING

# %%
a = float(input('Enter Research spent'))
b = float(input('Enter Office Administration spent'))
c = float(input('Enter Digital Marketing spent'))
d = input('Enter the Region')
Data = {'Research':[a],'Office Administation':[b],'Digital Marketing':[c],'Region':[d]}
df = pd.DataFrame(Data)
x = df.values
x[:,3] = labelencoder.transform(x[:,3])
x = onehotencoder.transform(x).toarray()
x = x[:,1:]
regressor.predict(x)
# Out:
# Enter Research spent280753.2
# Enter Office Administration spent149397.8
# Enter Digital Marketing spent16784.1
# Enter the RegionTelangana
# array([154397.34258806])

# %% [markdown]
# # STEP -8 MODEL DEPLOYMENT

# %%
import pickle
pkl_file = 'Multilinearregression'
with open(pkl_file,'wb') as file:
    pickle.dump(regressor,file)

# %%
pkl_file = 'Multilinearregression_L'
with open(pkl_file,'wb') as file:
    pickle.dump(labelencoder,file)

# %%
pkl_file = 'Multilinearregression_O'
with open(pkl_file,'wb') as file:
    pickle.dump(onehotencoder,file)
